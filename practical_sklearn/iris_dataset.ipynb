# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier   #try different model also like from sklearn.naive_bayes import GaussianNB
data=pd.read_excel("iris_train.xlsx")
data.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width        Class
# 0           5.7          4.4           1.5          0.4  Iris-setosa
# 1           5.5          4.2           1.4          0.2  Iris-setosa
# 2           5.2          4.1           1.5          0.1  Iris-setosa
# 3           5.8          4.0           1.2          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
x=data.iloc[:, :-1]  #take all columns except the last one

# %%
x
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width
# 0             5.7          4.4           1.5          0.4
# 1             5.5          4.2           1.4          0.2
# 2             5.2          4.1           1.5          0.1
# 3             5.8          4.0           1.2          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 111           4.5          2.3           1.3          0.3
# 112           6.2          2.2           4.5          1.5
# 113           6.0          2.2           5.0          1.5
# 114           6.0          2.2           4.0          1.0
# 115           5.0          2.0           3.5          1.0
#
# [116 rows x 4 columns]

# %%
y=data.iloc[: , -1]

# %%
y
# Out:
# 0          Iris-setosa
# 1          Iris-setosa
# 2          Iris-setosa
# 3          Iris-setosa
# 4          Iris-setosa
#             ...
# 111        Iris-setosa
# 112    Iris-versicolor
# 113     Iris-virginica
# 114    Iris-versicolor
# 115    Iris-versicolor
# Name: Class, Length: 116, dtype: object

# %%
#training the model
model=DecisionTreeClassifier()   #make changes here according to the model used.
model.fit(x.values,y.values)
# Out:
# DecisionTreeClassifier()

# %%
predictions=model.predict([[6.8,2.8,4.8,1.4]])

# %%
predictions
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
#Taking data from iris_test

# %%
datatest=pd.read_excel("iris_test.xlsx")

# %%
x_test=datatest.iloc[: , :-1]  #TAKE ALL COLUMNS EXCEPT THE LAST ONE

# %%
predictions=model.predict(x_test.values)

# %%
predictions
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
y_test=datatest.iloc[: ,-1]

# %%
actual=y_test.values

# %%
actual
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
count=0
for i in range(0,len(actual)):
 if actual[i]==predictions[i]:
    count=count+1
print((count*100)/len(actual))
# Out:
# 98.0
